# %%
#Problem 25

# %%
x=var('x')

# %%
s=var('s')

# %%
def P(x): return -.0006*x^3 + 0.28*x^2 + 55.6*x

# %%
plot(P(x),(x,0,500), color='blue', legend_label='P(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
P(50)
# Out:
# 3405.00000000000

# %%
s = 0

# %%
for x in range(0, 300, 50):
    s = s + P(x)*50
    print('x: ', x)
    print('P(x): ', P(x))
    print ('s:', s)
# Out:
# x:  0
# P(x):  0.000000000000000
# s: 0.000000000000000
# x:  50
# P(x):  3405.00000000000
# s: 170250.000000000
# x:  100
# P(x):  7760.00000000000
# s: 558250.000000000
# x:  150
# P(x):  12615.0000000000
# s: 1.18900000000000e6
# x:  200
# P(x):  17520.0000000000
# s: 2.06500000000000e6
# x:  250
# P(x):  22025.0000000000
# s: 3.16625000000000e6

# %%
s
# Out:
# 3.16625000000000e6

# %%
#Problem 29

# %%
x=var('x')

# %%
s=var('s')

# %%
def F(x): return 0.2*x^3 + 2*x^2 - 0.2*x - 2

# %%
plot(F(x),(x,-10,0), color='blue', legend_label='F(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
s = 0

# %%
for x in range(-8, -3):
    s = s + F(x)
    print('x: ', x)
    print('F(x): ', F(x))
    print ('s:', s)
# Out:
# x:  -8
# F(x):  25.2000000000000
# s: 25.2000000000000
# x:  -7
# F(x):  28.8000000000000
# s: 54.0000000000000
# x:  -6
# F(x):  28.0000000000000
# s: 82.0000000000000
# x:  -5
# F(x):  24.0000000000000
# s: 106.000000000000
# x:  -4
# F(x):  18.0000000000000
# s: 124.000000000000

# %%
s
# Out:
# 124.000000000000
